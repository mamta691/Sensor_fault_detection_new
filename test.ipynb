# %%
from sensor.utils import read_yaml_file
# Out:
# Reading .env file

# %%
read_yaml_file("/config/workspace/schema.yaml")
# Out:
# {'drop_columns': ['br_000',
#   'bq_000',
#   'bp_000',
#   'ab_000',
#   'cr_000',
#   'bo_000',
#   'bn_000'],
#  'target_column': 'class',
#  'required_columns': ['class',
#   'aa_000',
#   'ac_000',
#   'ad_000',
#   'ae_000',
#   'af_000',
#   'ag_000',
#   'ag_001',
#   'ag_002',
#   'ag_003',
#   'ag_004',
#   'ag_005',
#   'ag_006',
#   'ag_007',
#   'ag_008',
#   'ag_009',
#   'ah_000',
#   'ai_000',
#   'aj_000',
#   'ak_000',
#   'al_000',
#   'am_0',
#   'an_000',
#   'ao_000',
#   'ap_000',
#   'aq_000',
#   'ar_000',
#   'as_000',
#   'at_000',
#   'au_000',
#   'av_000',
#   'ax_000',
#   'ay_000',
#   'ay_001',
#   'ay_002',
#   'ay_003',
#   'ay_004',
#   'ay_005',
#   'ay_006',
#   'ay_007',
#   'ay_008',
#   'ay_009',
#   'az_000',
#   'az_001',
#   'az_002',
#   'az_003',
#   'az_004',
#   'az_005',
#   'az_006',
#   'az_007',
#   'az_008',
#   'az_009',
#   'ba_000',
#   'ba_001',
#   'ba_002',
#   'ba_003',
#   'ba_004',
#   'ba_005',
#   'ba_006',
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("/config/workspace/artifact/08_10_2023__10_30_13/data_ingestion/dataset/train.csv")

# %%
df
# Out:
#       class  aa_000  ab_000        ac_000  ad_000  ae_000  af_000  ag_000  \
# 0       neg    2748     NaN           NaN     NaN     NaN     NaN     0.0
# 1       neg     376     0.0  8.000000e+00     8.0     0.0     0.0     0.0
# 2       neg     362     2.0  2.200000e+01     NaN     0.0     0.0     0.0
# 3       neg  568254     0.0           NaN     NaN     NaN     NaN     0.0
# 4       neg      32     NaN  2.130706e+09    40.0     0.0     0.0     0.0
# ...     ...     ...     ...           ...     ...     ...     ...     ...
# 28945   neg     536     0.0  1.400000e+01    14.0     0.0     0.0     0.0
# 28946   neg   25018     NaN  7.200000e+01    42.0     0.0     0.0     0.0
# 28947   neg  102828     NaN  2.260000e+02   214.0     0.0     0.0     0.0
# 28948   neg   10564     NaN  2.130706e+09     NaN     0.0     0.0     0.0
# 28949   neg  171666     NaN  0.000000e+00  2610.0     0.0     0.0     0.0
#
#        ag_001  ag_002  ...     ee_002     ee_003     ee_004     ee_005  \
# ...

# %%
null_report=(df.isna().sum()*100)/df.shape[0]

# %%
list(null_report[null_report>5].index)
# Out:
# ['ab_000',
#  'ac_000',
#  'ad_000',
#  'ak_000',
#  'bk_000',
#  'bl_000',
#  'bm_000',
#  'bn_000',
#  'bo_000',
#  'bp_000',
#  'bq_000',
#  'br_000',
#  'bx_000',
#  'ca_000',
#  'cc_000',
#  'cf_000',
#  'cg_000',
#  'ch_000',
#  'cl_000',
#  'cm_000',
#  'co_000',
#  'cr_000',
#  'ct_000',
#  'cu_000',
#  'cv_000',
#  'cx_000',
#  'cy_000',
#  'cz_000',
#  'da_000',
#  'db_000',
#  'dc_000',
#  'df_000',
#  'dg_000',
#  'dh_000',
#  'di_000',
#  'dj_000',
#  'dk_000',
#  'dl_000',
#  'dm_000',
#  'eb_000',
#  'ec_00',
#  'ed_000']
